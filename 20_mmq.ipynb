# %%
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# # Metodo dos minimos quadradados

# %%
def mmq(x, y, k):
    n = len(x) # quantidade de pontos
    X = np.vander(x) #Matriz de Vandermonde
    X = X[:, n-k-1:n]  # Seleciona apenas as últimas k colunas
    a = np.linalg.solve(X.T @ X, X.T @ y)  # Resolve o sistema normal
    return a

# %%
# Dados fornecidos
# x = np.array([1, 2, 3, 4, 5])  # Pontos x
# y = np.array([1, 2, 5, 10, 4])  # Pontos y

import numpy as np

# Valores fornecidos para y
y = np.array([
    1, 1, 1, 2, 2, 2, 2, 3, 7, 13, 19, 25, 25, 34, 52, 77, 98, 121, 200, 234, 291, 428, 621, 904, 
    1128, 1546, 1891, 2201, 2433, 2915, 3417, 3903, 4256, 4579, 5717, 6834, 7910, 9056, 10278, 
    11130, 12056, 13717, 15927, 17857, 19638, 20727, 22169, 23430, 25262, 28320, 30425, 33682, 
    36599, 38654, 40581, 43079, 45757, 49492, 52995, 58509, 61888, 66501, 71886, 78162, 85380, 
    91299, 96396, 101147, 107780, 114715, 125218, 135106, 145328, 155939, 162699, 168331, 177589, 
    188974, 202918, 218223, 233142, 241080, 254220, 271628, 291579, 310087, 330890, 347398, 363211, 
    374898, 391222, 411821, 438238, 465166, 498440, 514200, 526447, 555383, 584016, 614941, 645771, 
    672846, 691758, 707412, 739503, 772416, 802828, 828810, 850514, 867624, 888271, 923189, 955377, 
    978142, 1032913, 1067579, 1085038, 1106470
])

# Gerando os valores de x automaticamente (índices correspondentes)
x = np.arange(1, len(y) + 1)


# Grau do polinômio
grau = 5

# Coeficientes do polinômio pelo MMQ
a = mmq(x, y, grau)

# Avaliação do polinômio ajustado
x_plot = np.linspace(min(x), max(x), 500)  # Intervalo para plotagem
y_plot = np.polyval(a, x_plot)  # Avalia o polinômio nos pontos x_plot (coeficientes já estão na ordem correta)

# Plotagem
plt.figure(figsize=(10, 6))

# Curva ajustada pelo MMQ
plt.plot(x_plot, y_plot, label=f'Ajuste MMQ (grau {grau})', color='blue', linewidth=2)

# Pontos originais
plt.scatter(x, y, color='red', label='Pontos originais', zorder=5)

# Configurações do gráfico
plt.xlabel('x', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.title('Ajuste de Curva por MMQ', fontsize=14)
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid(alpha=0.3)
plt.legend(fontsize=12)
plt.show()

# %%
def mmq(x, y, k):
    n = len(x) # quantidade de pontos
    X = np.vander(x) #Matriz de Vandermonde
    X = X[:, n-k-1:n]  # Seleciona apenas as últimas k colunas
    Q,R = np.linalg.qr(X)  # Decomposição QR
    a = np.linalg.solve(R, Q.T @ y)  # Resolve o sistema normal
    return a

# %%
# Dados fornecidos
# x = np.array([1, 2, 3, 4, 5])  # Pontos x
# y = np.array([1, 2, 5, 10, 4])  # Pontos y

import numpy as np

# Valores fornecidos para y
y = np.array([
    1, 1, 1, 2, 2, 2, 2, 3, 7, 13, 19, 25, 25, 34, 52, 77, 98, 121, 200, 234, 291, 428, 621, 904, 
    1128, 1546, 1891, 2201, 2433, 2915, 3417, 3903, 4256, 4579, 5717, 6834, 7910, 9056, 10278, 
    11130, 12056, 13717, 15927, 17857, 19638, 20727, 22169, 23430, 25262, 28320, 30425, 33682, 
    36599, 38654, 40581, 43079, 45757, 49492, 52995, 58509, 61888, 66501, 71886, 78162, 85380, 
    91299, 96396, 101147, 107780, 114715, 125218, 135106, 145328, 155939, 162699, 168331, 177589, 
    188974, 202918, 218223, 233142, 241080, 254220, 271628, 291579, 310087, 330890, 347398, 363211, 
    374898, 391222, 411821, 438238, 465166, 498440, 514200, 526447, 555383, 584016, 614941, 645771, 
    672846, 691758, 707412, 739503, 772416, 802828, 828810, 850514, 867624, 888271, 923189, 955377, 
    978142, 1032913, 1067579, 1085038, 1106470
])

# Gerando os valores de x automaticamente (índices correspondentes)
x = np.arange(1, len(y) + 1)


# Grau do polinômio
grau = 5

# Coeficientes do polinômio pelo MMQ
a = mmq(x, y, grau)

# Avaliação do polinômio ajustado
x_plot = np.linspace(min(x), max(x), 500)  # Intervalo para plotagem
y_plot = np.polyval(a, x_plot)  # Avalia o polinômio nos pontos x_plot (coeficientes já estão na ordem correta)

# Plotagem
plt.figure(figsize=(10, 6))

# Curva ajustada pelo MMQ
plt.plot(x_plot, y_plot, label=f'Ajuste MMQ (grau {grau})', color='blue', linewidth=2)

# Pontos originais
plt.scatter(x, y, color='red', label='Pontos originais', zorder=5)

# Configurações do gráfico
plt.xlabel('x', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.title('Ajuste de Curva por MMQ', fontsize=14)
plt.axhline(0, color='black', linewidth=0.5, linestyle='--')
plt.axvline(0, color='black', linewidth=0.5, linestyle='--')
plt.grid(alpha=0.3)
plt.legend(fontsize=12)
plt.show()
